# %% [markdown]
# <a href="https://colab.research.google.com/github/RiazullJannat/Python_For_Ai_Ml/blob/main/file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open("./sample_data/sample.txt", "r") as file:
  text = file.readlines()
  print(text)

print(file.closed)
# Out:
# ['hello world....\n', 'the quick brown fox jumps over the lazy dog.\n', ' ']
# True

# %%
with open("./sample_data/test.txt", "w") as file:
  file.write("How is going on?\n")
  file.write("what is your name?\n")

# %%
with open("./sample_data/test.txt", "w") as file:
  file.write("my name is rjannat")

# %%
with open("./sample_data/test.txt", "a") as file:
  file.write("i'm a good boy\n")
  file.write("yes now i can modify files....")

# %%
with open("./sample_data/test.txt", "r") as file:
  content = list(map(str.strip,filter(lambda x: len(x)>0,file.readlines())))
  #content = file.readlines()

  print(content)
# Out:
# ['How is going on?', 'what is your name?', "i'm a good boyi'm a good boy", 'yes now i can modify files....']

# %%
strings = ["the quick ", "brown fox ", "jumps over ", "the lazy ", "dog.\n"]
with open("./sample_data/test2.txt", "a") as file:
  file.writelines(strings)

with open("./sample_data/test2.txt", "r") as file:
  print(file.tell())
  content = file.readlines()
  print(file.tell())
# Out:
# 0
# 180
